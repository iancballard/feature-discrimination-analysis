# %%
##copy files from melodic output so I can look at them in melvie

# %%
import os
import numpy as np
import glob
import csv
import matplotlib
import matplotlib.pyplot as plt
import pandas as pd
from scipy import stats, optimize
from pandas import DataFrame, Series
import seaborn as sns
import random as rd
from statsmodels.formula.api import ols
from statsmodels.stats.anova import anova_lm
import scipy.stats
import multiprocessing

# %%
home_dir = '/Users/ianballard/Dropbox/fd/melodic/'
if not os.path.exists(home_dir):
    os.mkdir(home_dir)

subj_file = '/Users/ianballard/Dropbox/fd/scripts/subjects_ser.txt'
subjects = list(np.loadtxt(subj_file,'string'))

runs = ['1','2','3']
exp = ['sim','ser']

for sub in subjects:
    sub_dir = home_dir + sub + '/'
    if not os.path.exists(sub_dir):
        os.mkdir(sub_dir)
    
    for e in exp:
        exp_dir = sub_dir + e + '/'
        if not os.path.exists(exp_dir):
            os.mkdir(exp_dir)   
            
        for run in runs:
            run_dir = exp_dir + 'run_' + run + '/'
            if not os.path.exists(run_dir):
                os.mkdir(run_dir)

# %%
def copy_melodic(in_tuple):
    sub = in_tuple[0]
    e = in_tuple[1]
    run = in_tuple[2]
    
    remote_dir = ('iballard@cnic-smcclure.stanford.edu:/home/iballard/fd/analysis/' + e + '_8mm/'
                  + sub + '/preproc/run_' + run + '/melodic/filtered_func_data.ica')
    new_dir = home_dir + sub + '/' + e + '/' + 'run_' + run 
    cmd_str = 'scp -r ' +  remote_dir + ' ' + new_dir

    remote_dir = ('iballard@cnic-smcclure.stanford.edu:/home/iballard/fd/analysis/' + e + '_8mm/'
                  + sub + '/preproc/run_' + run + '/melodic/*txt')
    cmd_str = 'scp -r ' +  remote_dir + ' ' + new_dir

# %%
in_tuples = []
for sub in subjects:
    for e in exp:
        for run in runs:
            in_tuples.append((sub,e,run))
pool = multiprocessing.Pool(processes = 12)
pool.map(copy_melodic,in_tuples)
# Out:
# [None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
# ...

# %%
contrast = 'all'
exp = 'ser'
home_dir = '/Users/ianballard/Dropbox/fd/old_cleaned_' + contrast + '_' + exp + '/'
if not os.path.exists(home_dir):
    os.mkdir(home_dir)

subj_file = '/Users/ianballard/Dropbox/fd/subjects.txt'
subjects = list(np.loadtxt(subj_file,'string'))

runs = ['1','2','3']

for sub in subjects:
#     for exp in exp:
#     remote_dir = 'iballard@cnic-smcclure.stanford.edu:/home/iballard/fd/analysis/' + exp + '_8mm-PE/' \
#     + sub + '/uncleaned/ffx/mni/smoothed/' + contrast + '/zstat1.png'
    remote_dir = 'iballard@cnic-smcclure.stanford.edu:/home/iballard/fd/analysis/' + exp + '_8mm/' \
     + sub + '/ffx/mni/smoothed/' + contrast + '/zstat1.png'
    cmd_str = 'scp ' +  remote_dir + ' ' + home_dir + sub + '.png'
    print cmd_str
    os.system(cmd_str)
# Out:
# scp iballard@cnic-smcclure.stanford.edu:/home/iballard/fd/analysis/ser_8mm/fd_104/ffx/mni/smoothed/all/zstat1.png /Users/ianballard/Dropbox/fd/old_cleaned_all_ser/fd_104.png
# scp iballard@cnic-smcclure.stanford.edu:/home/iballard/fd/analysis/ser_8mm/fd_105/ffx/mni/smoothed/all/zstat1.png /Users/ianballard/Dropbox/fd/old_cleaned_all_ser/fd_105.png
# scp iballard@cnic-smcclure.stanford.edu:/home/iballard/fd/analysis/ser_8mm/fd_107/ffx/mni/smoothed/all/zstat1.png /Users/ianballard/Dropbox/fd/old_cleaned_all_ser/fd_107.png
# scp iballard@cnic-smcclure.stanford.edu:/home/iballard/fd/analysis/ser_8mm/fd_108/ffx/mni/smoothed/all/zstat1.png /Users/ianballard/Dropbox/fd/old_cleaned_all_ser/fd_108.png
# scp iballard@cnic-smcclure.stanford.edu:/home/iballard/fd/analysis/ser_8mm/fd_109/ffx/mni/smoothed/all/zstat1.png /Users/ianballard/Dropbox/fd/old_cleaned_all_ser/fd_109.png
# ...
